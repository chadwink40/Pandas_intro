# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv',index_col="ResponseId")

# %%
df.head(20)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                                       I am learning to code
# 5                              I am a developer by profession
# 6                                 I code primarily as a hobby
# 7           I am not primarily a developer, but I write co...
# 8                                       I am learning to code
# 9                                 I code primarily as a hobby
# 10                             I am a developer by profession
# 11          I used to be a developer by profession, but no...
# 12                             I am a developer by profession
# 13                             I am a developer by profession
# 14          I used to be a developer by profession, but no...
# ...

# %%
filta = (df['Country'] == 'India')

# %%
india_df = df.loc[filta]

# %%
india_df.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %%
india_df.to_csv('modified.csv')

# %%
india_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx', index_col = 'ResponseId')

# %%
test.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
#
#                         Age  \
# ResponseId
# 18          18-24 years old
# 59          18-24 years old
# 76          25-34 years old
# 90          25-34 years old
# 97          25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 18          Independent contractor, freelancer, or self-em...     Remote
# 59                                         Student, full-time        NaN
# 76                         Not employed, but looking for work        NaN
# 90                                        Employed, full-time  In-person
# ...

# %%
india_df.to_json('modified.json')

# %%
#india_df.to_json('modified.json', orient= 'records', lines = True)

# %%
# test = pd.read_json('modified.json', orient= 'records', lines = True) Reading from Json

# %%
#Writing to Sql.. Need Sql admin User name and Password
#from sqlalchemy import create_engine
#import psycopg2
#engine = create_engine("postgresql://dbuser:dbpass@locahost:5432/sample_db")setting up path for the Database connection
#india_df.to_sql("sample_table',engine, if_exist='replace') if the table already exist and you want to modify it

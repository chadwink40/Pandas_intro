# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv',index_col="ResponseId")

# %%
df.shape
# Out:
# (65437, 113)

# %%
pd.set_option('display.max_columns',114)

# %%
schema_df=pd.read_csv("survey_results_schema.csv", index_col="qname")

# %%
people = {"first" : ["Corey","Jane","John"],
          "last":["Schafer","Doe", "Doe"],
          "email":["coreyms@gmail.com","janedoe@gmail.com","johndoe@gmail.com"]}

# %%
dfp= pd.DataFrame(people)

# %%
dfp
# Out:
#    first     last              email
# 0  Corey  Schafer  coreyms@gmail.com
# 1   Jane      Doe  janedoe@gmail.com
# 2   John      Doe  johndoe@gmail.com

# %%
dfp.email
# Out:
# 0    coreyms@gmail.com
# 1    janedoe@gmail.com
# 2    johndoe@gmail.com
# Name: email, dtype: object

# %%
dfp.set_index('email', inplace=True)

# %%
dfp
# Out:
#                    first     last
# email
# coreyms@gmail.com  Corey  Schafer
# janedoe@gmail.com   Jane      Doe
# johndoe@gmail.com   John      Doe

# %%
dfp.index
# Out:
# Index(['coreyms@gmail.com', 'janedoe@gmail.com', 'johndoe@gmail.com'], dtype='object', name='email')

# %%
dfp.loc["janedoe@gmail.com", "last"]
# Out:
# 'Doe'

# %%
dfp.reset_index(inplace=False)
# Out:
#                email  first     last
# 0  coreyms@gmail.com  Corey  Schafer
# 1  janedoe@gmail.com   Jane      Doe
# 2  johndoe@gmail.com   John      Doe

# %%
dfp
# Out:
#                    first     last
# email
# coreyms@gmail.com  Corey  Schafer
# janedoe@gmail.com   Jane      Doe
# johndoe@gmail.com   John      Doe

# %%
df.head()
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
#
#                      Employment RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time     Remote  Apples
# 2           Employed, full-time     Remote  Apples
# 3           Employed, full-time     Remote  Apples
# 4            Student, full-time        NaN  Apples
# 5            Student, full-time        NaN  Apples
#
#                                              CodingActivities  \
# ResponseId
# 1                                                       Hobby
# 2           Hobby;Contribute to open-source projects;Other...
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID316  How much do you trust the accuracy of the outp...
# AIBen         QID324  For the AI tools you use as part of your devel...
# AIChallenges  QID346  What are the challenges to your company/whole ...
# AIComplex     QID343  How well do the AI tools you use in your devel...
# AIEthics      QID339  Which AI ethical responsibilities are most imp...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     SAVR
# ...

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
#Filtering

# %%
filt =(dfp['last'] == 'Schafer') | (dfp['first']=='John')

# %%
dfp[~filt]
# Out:
#                   first last
# email
# janedoe@gmail.com  Jane  Doe

# %%
dfp.loc[~filt]
# Out:
#                   first last
# email
# janedoe@gmail.com  Jane  Doe

# %%
filta = df['LanguageHaveWorkedWith'].str.contains('Python', na= False)

# %%
high_salary = df['ConvertedCompYearly'] > 70000

# %%
df.loc[
high_salary,
['LanguageHaveWorkedWith','Country','Age','Annual_Salary_USD']].nlargest(50,'Annual_Salary_USD').sort_values(by=['Country','Annual_Salary_USD'],ascending = [True, True])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df.loc[
#       2 high_salary,
#       3 ['LanguageHaveWorkedWith','Country','Age','Annual_Salary_USD']].nlargest(50,'Annual_Salary_USD').sort_values(by=['Country','Annual_Salary_USD'],ascending = [True, True])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# ...

# %%
df

# %%
dfp

# %%
dfp.columns

# %%
dfp.columns = ["first_name","last_name","email"]

# %%
dfp

# %%
dfp.columns = [x.lower() for x in dfp.columns]

# %%
dfp

# %%
dfp.columns= dfp.columns.str.replace('_', '')

# %%
dfp

# %%
dfp.rename(columns = {'firstname':'First','lastname':'Last'},inplace=True)

# %%
dfp

# %%
dfp.loc[2]=['John','Smith','JohnSmith@email.com']

# %%
dfp

# %%
dfp['email']=dfp['email'].str.lower()

# %%
dfp

# %%
filt = dfp['email'] == 'janedoe@gmail.com'

# %%
filt

# %%
dfp.loc[filt,'Last'] = 'Smith'

# %%
dfp

# %%
#updating rows and Columns Ussing APPLY,MAP,APPLYMAP.REPLACE

# %%
dfp['email']

# %%
dfp['email']= dfp['email'].apply(lambda x: x.upper())

# %%
dfp

# %%
dfp.map(len)

# %%
dfp.applymap(len)

# %%
df

# %%
df.rename(columns = {'ConvertedCompYearly':'Annual_Salary_USD'},inplace=True)

# %%
df

# %%
df['Annual_Salary_USD']

# %%
df.head()

# %%
df.head()

# %%
dfp

# %%
dfp["full_name"] = dfp['first']+ ' ' + dfp['last']

# %%
dfp

# %%
dfp.drop(columns=['first','last'],inplace = True)

# %%
dfp

# %%
dfp['full_name'].str.split(' ', expand = True)

# %%
dfp[['First','Last']] = dfp['full_name'].str.split(' ', expand = True)

# %%
dfp

# %%
dfp.reset_index(inplace=True)

# %%
dfp

# %%
people = {"first" : ["Steve","Jimoh"],
          "last":["Scopy","Lemar"],
          "email":["stevescopy@gmail.com","jimohdog@gmail.com"]}
dfp1 = pd.DataFrame(people)

# %%
dfp._append(dfp1,ignore_index = True)

# %%
dfp = dfp._append(dfp1,ignore_index = True)

# %%
dfp

# %%
dfp.drop(index=4)

# %%
dfp.sort_values(by=['Last', 'First'], ascending = (False, True))

# %%
dfp.sort_index()

# %%
dfp

# %%
df.sort_values(by=['Country','Annual_Salary_USD'],ascending = [True, False],inplace = True)

# %%
df[['Country','Annual_Salary_USD']].head(50)

# %%
df['Annual_Salary_USD'].nlargest(10)

# %%
top_10 = df.nlargest(10,'Annual_Salary_USD')

# %%
top_10

# %%
df.head(5)

# %%
dfp

# %%
df['ConvertedCompYearly'].head(15)

# %%
df.describe()

# %%
df['ConvertedCompYearly'].value_counts()

# %%
schema_df.head(50)

# %%
#Grouping Split, Group by combining function and applying the function

# %%
df['Country'].value_counts()

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
# C:\Users\sodiq\AppData\Local\Temp\ipykernel_14612\421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 59          I am not primarily a developer, but I write co...
# 76                                      I am learning to code
# 90                                      I am learning to code
# 97                             I am a developer by profession
# ...                                                       ...
# 65340       I am not primarily a developer, but I write co...
# 65384                                   I am learning to code
# 65414                                   I am learning to code
# ...

# %%
filya = df['Country'] == 'India'

# %%
filya

# %%
df.loc[filya]['SOAccount'].value_counts()

# %%
country_grp['SOAccount'].value_counts(normalize = True).loc['Germany']

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']

# %%
country_grp['ConvertedCompYearly'].agg(['mean','median']).loc['India']

# %%
filya = df['Country'] == 'India'
df.loc[filya]['LanguageHaveWorkedWith'].str.contains('Python').sum()

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
#                                                         ...
# Central African Republic                                    1
# Equatorial Guinea                                           1
# Niger                                                       1
# Guinea                                                      1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
Country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
Country_uses_python
# Out:
# Country
# Afghanistan                              26
# Albania                                  10
# Algeria                                  37
# Andorra                                   8
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     25
# Viet Nam                                138
# Yemen                                    10
# Zambia                                    8
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df= pd.concat([country_respondents, Country_uses_python],axis='columns', sort=False)

# %%
python_df.rename(columns = {'count': 'TotalRespondents', 'LanguageHaveWorkedWith':'PythonUser'},inplace = True)

# %%
python_df
# Out:
#                                                     TotalRespondents  \
# Country
# United States of America                                       11095
# Germany                                                         4947
# India                                                           4231
# United Kingdom of Great Britain and Northern Ir...              3224
# Ukraine                                                         2672
# ...                                                              ...
# Central African Republic                                           1
# Equatorial Guinea                                                  1
# Niger                                                              1
# Guinea                                                             1
# Solomon Islands                                                    1
#
#                                                     PythonUser
# Country
# ...

# %%
python_df['PctPythonUsers']= (python_df['PythonUser']/python_df['TotalRespondents'])*100
python_df
# Out:
#                                                     TotalRespondents  \
# Country
# United States of America                                       11095
# Germany                                                         4947
# India                                                           4231
# United Kingdom of Great Britain and Northern Ir...              3224
# Ukraine                                                         2672
# ...                                                              ...
# Central African Republic                                           1
# Equatorial Guinea                                                  1
# Niger                                                              1
# Guinea                                                             1
# Solomon Islands                                                    1
#
#                                                     PythonUser  PctPythonUsers
# Country
# ...

# %%
python_df.sort_values(by= 'PctPythonUsers', ascending=False).head(50)
# Out:
#                                   TotalRespondents  PythonUser  PctPythonUsers
# Country
# Niger                                            1           1      100.000000
# Central African Republic                         1           1      100.000000
# Samoa                                            1           1      100.000000
# Lesotho                                          1           1      100.000000
# Saint Kitts and Nevis                            1           1      100.000000
# Dominica                                         1           1      100.000000
# Chad                                             1           1      100.000000
# Belize                                           2           2      100.000000
# Brunei Darussalam                                3           3      100.000000
# Mauritania                                       5           4       80.000000
# Liberia                                          4           3       75.000000
# ...

# %%
python_df.loc['Finland']
# Out:
# TotalRespondents    386.000000
# PythonUser          207.000000
# PctPythonUsers       53.626943
# Name: Finland, dtype: float64

# %%
df
# Out:
#                                 MainBranch                 Age  \
# ResponseId
# 1           I am a developer by profession  Under 18 years old
# 2           I am a developer by profession     35-44 years old
# 3           I am a developer by profession     45-54 years old
# 4                    I am learning to code     18-24 years old
# 5           I am a developer by profession     18-24 years old
# ...                                    ...                 ...
# 65433       I am a developer by profession     18-24 years old
# 65434       I am a developer by profession     25-34 years old
# 65435       I am a developer by profession     25-34 years old
# 65436       I am a developer by profession     18-24 years old
# 65437          I code primarily as a hobby     18-24 years old
#
#                      Employment                            RemoteWork   Check  \
# ResponseId
# 1           Employed, full-time                                Remote  Apples
# ...

# %%
dfp
# Out:
#                    first     last
# email
# coreyms@gmail.com  Corey  Schafer
# janedoe@gmail.com   Jane      Doe
# johndoe@gmail.com   John      Doe

# %%
import numpy as np

# %%
people = {"first" : ["Corey","Jane","John",'James',np.nan,None,'Na'],
          "last":["Schafer","Doe", "Doe","Gaf",np.nan,np.nan,'Missing'],
          "email":["coreyms@gmail.com","janedoe@gmail.com","johndoe@gmail.com",None,np.nan,'Na','anonymous@gmail.com'],
           "age": ["33","55","63","23",None,None,"Missing"]}

# %%
dfp = pd.DataFrame(people)
dfp.replace('Na',np.nan, inplace = True)
dfp.replace('Missing',np.nan, inplace= True)

# %%
dfp
# Out:
#    first     last                email   age
# 0  Corey  Schafer    coreyms@gmail.com    33
# 1   Jane      Doe    janedoe@gmail.com    55
# 2   John      Doe    johndoe@gmail.com    63
# 3  James      Gaf                 None    23
# 4    NaN      NaN                  NaN  None
# 5   None      NaN                   Na  None
# 6     Na      NaN  anonymous@gmail.com   NaN

# %%
dfp.dropna()
# Out:
#    first     last              email age
# 0  Corey  Schafer  coreyms@gmail.com  33
# 1   Jane      Doe  janedoe@gmail.com  55
# 2   John      Doe  johndoe@gmail.com  63

# %%
dfp.dropna(axis='index', how= 'any')
# Out:
#    first     last              email age
# 0  Corey  Schafer  coreyms@gmail.com  33
# 1   Jane      Doe  janedoe@gmail.com  55
# 2   John      Doe  johndoe@gmail.com  63

# %%
dfp.fillna()
# Out:
#    first     last                email age
# 0  Corey  Schafer    coreyms@gmail.com  33
# 1   Jane      Doe    janedoe@gmail.com  55
# 2   John      Doe    johndoe@gmail.com  63
# 3  James      Gaf                    0  23
# 4      0        0                    0   0
# 5      0        0                    0   0
# 6      0        0  anonymous@gmail.com   0

# %%
dfp['age']= dfp['age'].astype(float)

# %%
dfp.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
dfp['age'].mean()
# Out:
# 43.5

# %%
df['Age'].unique()
# Out:
# array(['Under 18 years old', '35-44 years old', '45-54 years old',
#        '18-24 years old', '25-34 years old', '55-64 years old',
#        'Prefer not to say', '65 years or older'], dtype=object)
